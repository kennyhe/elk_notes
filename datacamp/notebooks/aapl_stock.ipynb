# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
aapl = pd.read_csv('aapl.csv', index_col='Date', parse_dates=True)

# %%
aapl.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79

# %%
close_arr = aapl['Close'].values

# %%
close_arr
type(close_arr)
# Out:
# numpy.ndarray

# %%
plt.plot(close_arr)

# %%
close_series = aapl['Close']

# %%
type(close_series)
# Out:
# pandas.core.series.Series

# %%
plt.plot(close_series)

# %%
close_series.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aapl.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.plot(aapl)
plt.yscale('log')

# %%
aapl['Open'].plot(color='b', style='.-', legend=True)
aapl['Close'].plot(color='r', style='-', legend=True)
plt.axis(('2001','2002',14,25))
plt.savefig('aapl1.png')

# %%
aapl.loc['2001':'2006', ['Open', 'Close', 'High', 'Low']].plot()
plt.savefig('aapl2.pdf')

# %%
aapl.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79

# %%
aapl.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  6081.000000  6081.000000  6081.000000  6081.000000  6.081000e+03
# mean     46.823511    47.681506    45.913595    46.798619  1.363986e+07
# std      33.993517    34.578077    33.273106    33.947235  1.352107e+07
# min      12.880000    13.190000    12.720000    12.940000  8.880000e+04
# 25%      24.730000    25.010000    24.200000    24.690000  5.530000e+06
# 50%      38.250000    38.880000    37.460000    38.130000  8.976400e+06
# 75%      53.500000    54.550000    52.500000    53.610000  1.631920e+07
# max     200.590000   202.960000   197.800000   199.830000  2.650690e+08
#
#          Adj Close
# count  6081.000000
# mean     23.529794
# std      37.375601
# min       1.650000
# 25%       7.380000
# 50%       9.910000
# 75%      14.360000
# max     199.830000

# %%
import matplotlib.pyplot as plt
plt.plot(aapl)
plt.ylabel('some numbers')
plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-63a8e4a7d7a0> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(aapl)
#       3 plt.ylabel('some numbers')
#       4 plt.yscale('log')
#       5 plt.show()
#
# NameError: name 'aapl' is not defined

# %%
plt.plot(aapl)
plt.yscale('log')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.yscale('log')

# %%
plt.yscale('log')
